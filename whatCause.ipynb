# %%
import pandas as pd

# %% [markdown]
# File này dùng để trực quan hóa

# %%
df=pd.read_csv("dataset/data.csv")
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol  Systolic blood pressure  \
# 0    BMW7812   67    Male          208                      158
# 1    CZE1114   21    Male          389                      165
# 2    BNI9906   21  Female          324                      174
# 3    JLN3497   84    Male          383                      163
# 4    GFO8847   66    Male          318                       91
#
#    Diastolic blood pressure  Heart Rate  Diabetes  Family History  Smoking  \
# 0                        88          72         0               0        1
# 1                        93          98         1               1        1
# 2                        99          72         1               0        0
# 3                       100          73         1               1        1
# 4                        88          93         1               1        1
#
#    ...  Medication Use  Stress Level  Sedentary Hours Per Day        BMI  \
# ...
